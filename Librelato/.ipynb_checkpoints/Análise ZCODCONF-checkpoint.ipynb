# %% [markdown]
# ### Objetivo Geral
#
#  Analisar códigos do configurador de produtos (todo histórico do configurador)
#
# ### Objetivos Especifícos
#
#  Quantificar códigos unicos do configurador
#
#  Quantiticar quantidade de vezes que um código do configurador foi utilizado
#
#  Quantificar códigos unicos do protheus (genérico)
#
#  Quantificar quantidade de vezes que um código do protheus (genérico) foi utilizado
#
#  Listar produtos mais vendidos por código do protheus (genérico)

# %%
# Importar Lib matpltlib
import matplotlib.pyplot as plt
# Importar lib para conectar ao banco de dados
import pyodbc
# Importar lib pandas
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# Parâmetros para conectar ao banco de dados
server = '192.168.5.249' 
database = 'dadosadv' 
username = 'manager' 
password = '' 
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

# %%
cursor = cnxn.cursor()

sql = """
   SELECT COUNT(1) QTD,
          B1_ZCODCFG,
          B1_DESC
     FROM SC5010 C5 (NOLOCK)
     JOIN SC6010 C6 (NOLOCK)
       ON C6.C6_NUM = C5.C5_NUM
      AND C6.C6_FILIAL = C5.C5_FILIAL
      AND C6.D_E_L_E_T_ = ''
     JOIN SB1010 B1 (NOLOCK)
       ON B1.B1_COD = C6_PRODUTO
      AND B1.D_E_L_E_T_ = ''
    WHERE C5.D_E_L_E_T_ = ''
   -- AND C5.C5_EMISSAO >= '20190101' LINHA COMENTADA, NÃO CONSIDERADA NA PESQUISA
      AND B1_ZCODCFG <> ''
 GROUP BY B1_ZCODCFG, B1_DESC
 ORDER BY QTD DESC
"""

data = pd.read_sql(sql,cnxn)

# %%
# Quantidade unica de códigos CONFIGURADOR gerados
data['B1_ZCODCFG'].nunique()
# Out:
# 7355

# %% [markdown]
# ![alt text](configurador/1.png "Configurador")

# %% [markdown]
# ![alt text](configurador/2.png "Configurador")

# %% [markdown]
# ![alt text](configurador/4.png "Configurador")

# %% [markdown]
# ![alt text](configurador/5.png "Configurador")

# %% [markdown]
# ![alt text](configurador/6.png "Configurador")

# %% [markdown]
# ![alt text](configurador/7.png "Configurador")

# %% [markdown]
# ![alt text](configurador/8.png "Configurador")

# %% [markdown]
# ![alt text](configurador/9.png "Configurador")

# %% [markdown]
# ![alt text](configurador/10.png "Configurador")

# %% [markdown]
# ![alt text](configurador/11.png "Configurador")

# %% [markdown]
# ![alt text](configurador/12.png "Configurador")

# %% [markdown]
# ![alt text](configurador/13.png "Configurador")

# %%
data[['B1_ZCODCFG','B1_DESC']]
# Out:
#                                                                                  B1_ZCODCFG  \
# 0     1765B13311000001210112220K9110017A200001112000000010000000000000000000000000000000000
# 1     1765B13311000001210112220D9110017A200001112000000010000000000000000000000000000000000
# 2     1765713231000001200112220K9110017A200001012000000010000000000000000000000000000000000
# 3     1765B13311000001210112220O9110017A200001112000000010000000000000000000000000000000000
# 4     141177292210000211031811011110017A213A31112151120010000011000H03321116011001119000000
# 5     14117829221100020101681101111002112211211121111200100000z1000K0122111121100153z000000
# 6     1765713531000001000112220K9110017A200001012000000010000000000000000000000000000000000
# 7     1765B1331100000121011211011110017A200001112000000010000000000000000000000000000000000
# 8     1765B13311000001210112220J9110017A200001112000000010000000000000000000000000000000000
# 7443  BITREM BASCULANTE DIANTEIRO 2 EIXOS JUNTOS MECANICOS 25 M3
# 7444  BITREM BASCULANTE DIANTEIRO 2 EIXOS JUNTOS MECANICOS 25 M3
# 7445  BITREM BASCULANTE DIANTEIRO 2 EIXOS JUNTOS MECANICOS 25 M3
# 7446  BITREM BASCULANTE DIANTEIRO 2 EIXOS JUNTOS MECANICOS 25 M3
# 7447  BITREM BASCULANTE TRASEIRO 2 EIXOS JUNTOS MECANICOS 25 M3
# 7448  BITREM BASCULANTE TRASEIRO 2 EIXOS JUNTOS MECANICOS 25 M3
#
# [7449 rows x 2 columns]

# %%
# Quantidade de vezes (até) que 80% dos códigos dos configurador foram utilizados (Dados em ROL).
data['QTD'].quantile([0.80])
# Out:
# 0.8    4.0
# Name: QTD, dtype: float64

# %%
# Quantidade de vezes que um código CONFIGURADOR foi utilizado
data_qtd = data['QTD'].value_counts().sort_index()

# %%
# Quantidade de pedidos que foram criados com cada código.
## Procedimentos abaixo (linhas 3,4,5), convertem a contagem (em inteiro) para datafram
df_val_counts = data_qtd
df_value_counts = data_qtd.reset_index()
# Trocar Nomes das Colunas
df_value_counts.columns = ['QTD', 'CONT'] 
## Criar coluna com qtd x cont
df_value_counts['QTD_PROD_GERADOS'] = df_value_counts['QTD'] * df_value_counts['CONT']

# %%
# Quantidade de códigos do CONFIGURADOR (y) x Quantas vezes foi utilizado (x)
df_value_counts.plot.bar(x='QTD',y='CONT',figsize=(20,7))

# %%
# Quantidade de pedidos gerados, através dos códigos códigos relacionados acima
df_value_counts.plot.bar(x='QTD',y='QTD_PROD_GERADOS',figsize=(20,7))

# %%
# Eliminar coluna do cod do configurador, para possibilitar agrupamento por descrição
data_simple = data.drop(['B1_ZCODCFG'], axis=1)
# Agrupar data por descrição genérica, somar totais, e organizar em ROL
data_simple_group = data_simple.groupby('B1_DESC').sum().sort_values('QTD', ascending=0).reset_index()

# %%
# Quantidade de produtos (códigos agrupados) utilizados do configurador de produtos
data_simple_group['B1_DESC'].nunique()
# Out:
# 493

# %%
# Quantidade de produtos mais utilizados dos códigos do configurador
chart2 = data_simple_group.head(50).plot.bar(x='B1_DESC', y='QTD', rot=0,figsize=(20,7))
chart2.set_xticklabels(chart2.get_xticklabels(), rotation=90)
chart2

# %%
data_simple_group
# Out:
#                                                                               B1_DESC  \
# 0    REBOQUE DOLLY REBOQUE 2 EIXOS JUNTOS MECANICOS 5600 MM
# 1    SEMIRREBOQUE GRANELEIRO 3 EIXOS JUNTOS MECANICOS 12500 MM
# 2    RODOTREM BASCULANTE DIANTEIRO 2 EIXOS JUNTOS MECANICOS 35 M3
# 3    RODOTREM BASCULANTE TRASEIRO 2 EIXOS JUNTOS MECANICOS 35 M3
# 4    BITREM BASCULANTE DIANTEIRO 2 EIXOS JUNTOS MECANICOS 25 M3
# 5    BITREM BASCULANTE TRASEIRO 2 EIXOS JUNTOS MECANICOS 25 M3
# 6    BITRENZAO GRANELEIRO TRASEIRO 3 EIXOS JUNTOS MECANICOS 11500 MM
# 7    RODOTREM GRANELEIRO DIANTEIRO 2 EIXOS JUNTOS MECANICOS 9400 MM
# 472  SEMIRREBOQUE CARREGA TUDO 2 EIXOS JUNTOS MECANICOS 4000 MM
# 473  SEMIRREBOQUE SIDER 3 EIXOS DISTANCIADOS PNEUMATICOS (1+1+1) 15000 MM
# 474  SEMIRREBOQUE CARGA SECA 3 EIXOS JUNTOS MECANICOS 13500MM
# 475  SEMIRREBOQUE CARGA SECA 3 EIXOS JUNTOS MECANICOS 13000 MM
# 476  SEMIRREBOQUE CARREGA TUDO 4 EIXOS MECANICOS JUNTOS 8230 MM
# 477  SEMIRREBOQUE CARGA SECA 3 EIXOS JUNTOS MECANICOS 10500 MM
# 478  SEMIRREBOQUE CARGA SECA 3 EIXOS DISTANCIADOS PNEUM AUTODIRECIONAL COM RALA 12500
# 479  SEMIRREBOQUE BASCULANTE 3 EIXOS JUNTOS MECANICOS 20
# 480  SEMIRREBOQUE CARGA SECA 3 EIXOS DISTANCIADOS MISTOS AUTODIRECIONAL COM MANGA 125
# 481  SEMIRREBOQUE SIDER 2 EIXOS DISTANCIADOS PNEUMATICOS (1+1) 13500 MM
# 482  SEMIRREBOQUE SIDER 2 EIXOS DISTANCIADOS PNEUMATICOS (1+1) 11000 MM
# 483  SEMIRREBOQUE CARGA SECA 2 EIXOS DISTANCIADOS PNEUMATICOS 12500MM
# 484  SEMIRREBOQUE SIDER 2 EIXOS DISTANCIADOS MISTOS (1+1) 11500 MM
# 485  SEMIRREBOQUE DOLLY 2 EIXOS JUNTOSMECANICOS 6100 MM
# 486  SEMIRREBOQUE FRIGORIFICA 03 EIXOS JUNTOS
# 487  SEMIRREBOQUE FRIGORIFICA 3 EIXOS JUNTOS MECANICOS 14600
# 488  SEMIRREBOQUE SILO 2 EIXOS JUNTOS PNEUMATICOS 36 M3
# 489  SEMIRREBOQUE TANQUE ACO CARBONO CILINDRICO 3 EIXOS DISTANCIADOS PNEUM AUTODIRECI
# 490  SEMIRREBOQUE BASCULANTE 3 EIXOS JUNTOS MECANICOS 23
# 491  SEMIRREBOQUE PORTA CONTAINER 2 EIXOS JUNTOS MECANICOS 4 PINOS (1 X 40 PES)
# 492  RODOTREM GRANELEIRO DIANTEIRO 2 EIXOS JUNTOS MECANICOS 12500MM
#
#       QTD
# 0    1834
# 1    1539
# 2    1229
# 3    1197
# 4    1157
# 5    1111
# 6    909
# 7    806
# 8    802
# 9    767
# 10   762
# 11   679
# 12   663
# 13   662
# 14   575
# 15   516
# 16   509
# 17   486
# 18   482
# 19   386
# 20   383
# 21   375
# 22   249
# 23   238
# 24   237
# 25   232
# 26   221
# 27   218
# 28   215
# 29   196
# ..   ...
# 463  1
# 464  1
# 465  1
# 466  1
# 467  1
# 468  1
# 469  1
# 470  1
# 471  1
# 472  1
# 473  1
# 474  1
# 475  1
# 476  1
# 477  1
# 478  1
# 479  1
# 480  1
# 481  1
# 482  1
# 483  1
# 484  1
# 485  1
# 486  1
# 487  1
# 488  1
# 489  1
# 490  1
# 491  1
# 492  1
#
# [493 rows x 2 columns]

# %% [markdown]
# #### Resultados esperados da análise
#   * Questionamento sobre modelo de negócio adotado pela organização (nível de configuração de um produto)
#   * Definição do nível de integração entre portal representante vs protheus
